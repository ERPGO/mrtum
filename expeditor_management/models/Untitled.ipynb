# %%
env['ir.ui.menu'].search([('name','=','Inventory')]).fields_get()
# Out:
# {'name': {'type': 'char',
#   'change_default': False,
#   'company_dependent': False,
#   'depends': (),
#   'manual': False,
#   'readonly': False,
#   'required': True,
#   'searchable': True,
#   'sortable': True,
#   'store': True,
#   'string': 'Menu',
#   'translate': True,
#   'trim': True},
#  'active': {'type': 'boolean',
#   'change_default': False,
#   'company_dependent': False,
#   'depends': (),
#   'manual': False,
#   'readonly': False,
#   'required': False,
#   'searchable': True,
#   'sortable': True,
#   'store': True,
#   'string': 'Active'},
#  'sequence': {'type': 'integer',
#   'change_default': False,
#   'company_dependent': False,
#   'depends': (),
#   'group_operator': 'sum',
#   'manual': False,
#   'readonly': False,
#   'required': False,
#   'searchable': True,
#   'sortable': True,
#   'store': True,
#   'string': 'Sequence'},
#  'child_id': {'type': 'one2many',
#   'change_default': False,
#   'company_dependent': False,
#   'context': {},
# ...
